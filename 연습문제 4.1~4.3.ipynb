# %% [markdown]
# 연습문제 4.1.1

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - 부호 함수

# %%
np.sign(10), np.sign(-100), np.sign(0)
# Out:
# (1, -1, 0)

# %%
x = np.linspace(-1, 10, 300)
y = np.sign(x)

plt.plot(x,y)
plt.xlim(-2,11)
plt.ylim(-2,2)
plt.show()

# %% [markdown]
# - 단위계단 함수

# %%
def danwi_function(x):
    if isinstance(x, np.ndarray):
        return np.where(x >= 0,1,0)
    else:
        return 1.0 if x >= 0 else 0.0
danwi_function(-100), danwi_function(0), danwi_function(10)
# Out:
# (0.0, 1.0, 1.0)

# %%
x = np.linspace(-1,10,300)
y = danwi_function(x)

plt.plot(x, y)
plt.xlim(-2, 11)
plt.ylim(-1, 2)
plt.show()

# %% [markdown]
# 연습문제 4.1.2

# %%
np.log(12)
# Out:
# 2.4849066497880004

# %% [markdown]
# 연습문제 4.1.3

# %%
import matplotlib.pyplot as plt

def f1(x):
    return x ** 2

def f1inv(x):
    return np.sqrt(x)

x = np.linspace(0, 3, 300)
plt.plot(x, f1(x), "r-", label="function $f(x) = x^2$")
plt.plot(x, f1inv(x), "b-.", label ="inv-functioin $f^{-1}(x) = \sqrt{x}$")
plt.plot(x, x, "g--")
plt.xlim(0,2)
plt.ylim(0,2)
plt.legend()
plt.title("inverse function graph")

plt.show();

# %% [markdown]
# 연습문제 4.2.1

# %%
def f(x):
    return x**3 - 3 * x**2 + x

x = np.linspace(-1, 3, 400)
y = f(x)

plt.plot(x, y)
plt.plot(0, 0, 'ro')
plt.plot(x, x, 'r:')
plt.plot(1, -1, 'go')
plt.plot(x, (3*1**2-6*1+1)*(x-1)-1, 'g--')

plt.xlim(-3.5, 5.5)
plt.ylim(-4, 2)
plt.xticks(np.arange(-3, 6))
plt.yticks(np.arange(-4, 2))

plt.annotate('', xy=(1, 0), xytext=(0, 0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(1, 1), xytext=(1, 0), arrowprops=dict(facecolor='gray'))

plt.annotate('', xy=(2, -1), xytext=(1, -1), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(2, -3), xytext=(2, -1), arrowprops=dict(facecolor='gray'))

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("function's gradient")
plt.show()
